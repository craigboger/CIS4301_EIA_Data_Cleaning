# %%
import pandas as pd

data = pd.read_excel('/content/drive/My Drive/CIS4301_EIA_Data_Cleaning/organizedData/2_utility/1___Utility_Y2016.xlsx', skiprows = 1)

data.rename(columns={'Utility ID':'util_ID',
                     'Utility Name':'util_name',
                     'Street Address':'street_address',
                     'City':'city',
                     'State':'state',
                     'Zip':'zip',
                     'Entity Type':'entity_type_id'},
                     inplace=True)

df = pd.DataFrame(data, columns= ['util_ID',
                                   'util_name',
                                   'street_address',
                                   'city',
                                   'state',
                                   'zip',
                                   'entity_type_id'])

# Need to figure out how to break long lines like the one below
df.to_csv('/content/drive/My Drive/CIS4301_EIA_Data_Cleaning/Test_Pandas_John/Post_Panda_Data_Files/utility_2016.csv',
          index = False)

#=============Just test stuff below=====================================
#df.columns
#print(df1.head(10))
#bool_series = data.isnull(df['entity_type'])
#df[bool_series]

#dict = {'entity_type_ID':['IND', 'Q', 'C', 'M', 'I', 'P', 'youwza']} 
  
# creating a dataframe using dictionary 
#df1 = pd.DataFrame(dict) 
  
# using notnull() function  
#df1.notnull()

#A = df.loc[df["entity_type_ID"].isnull()]
#df.loc[df["entity_type_ID"]=='IND']
#print(A.head(20))
#df.columns[df.isnull().any()]
#print(B.head(20))
