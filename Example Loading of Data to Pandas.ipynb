# %% [markdown]
# #Importing and Loading Excel Files from EIA Data on Google Drive

# %%
#Get Pandas
import pandas as pd

# %%
#Read the Excel File
testDF = pd.read_excel('/content/drive/My Drive/CIS4301_EIA_Data_Cleaning/organizedData/2_utility/Utility_Y2018.xlsx')

# %%
#Print the data frame.
testDF
# Out:
#      2018 Form EIA-860 Data - Schedule 1, 'Utility Data'  ...  Unnamed: 10
# 0                                            Utility ID   ...  Entity Type
# 1                                                     7   ...          IND
# 2                                                     8   ...          IND
# 3                                                    21   ...            Q
# 4                                                    25   ...            Q
# ...                                                 ...   ...          ...
# 5035                                              62778   ...            Q
# 5036                                              62784   ...            Q
# 5037                                              62787   ...            Q
# 5038                                              62788   ...            Q
# 5039                                              62789   ...            Q
#
# [5040 rows x 11 columns]

# %%
#Testing adding changes with a previous revision saved.
